# %%
import yfinance as yf
import requests
import pandas as pd
import datetime as dt
import time
from datetime import timedelta
from prod.model import *
from functools import reduce
from yahoo_fin import stock_info as si
from yahoo_fin import get_data
import numpy as np
import gspread
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials
import pygsheets

# %%
initial_amount=5000000/777.18

# ponderacion del portafolio
ponderacion={'ETHO':4.06/100,
'ESGV':4.12/100,
'VT':12.16/100,
'XLK':15.16/100,
'VTI':19.61/100,
'IVV':11.42/100,
'QQQ':15.30/100,
'ESGU':4.79/100,
'SMH':6.72/100,
'ARKW':2.30/100,
'ARKK':2.13/100
}
#'OTROS':2.23/100
get_data("QQQ", start_date="10/20/2019")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-75325d5931da> in <module>
#      15 }
#      16 #'OTROS':2.23/100
# ---> 17 get_data("QQQ", start_date="10/20/2019")
#
# NameError: name 'get_data' is not defined

# %%
ticker('QQQ').getLatest()
# Out:
# Creating ticker ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-83ce48a3aa2b> in <module>
# ----> 1 ticker('QQQ').getLatest()
#
# ~/Develop/tieup/tieup/codes/prod/model.py in getLatest(self)
#      75
#      76         # Obtenemos los ultimos registros para el dia actual
# ---> 77         data=get_data(self.name , start_date = self.today)
#      78         print(str(self.name) + str(" was created, date:") + str(self.today) )
#      79
#
# ~/miniconda3/lib/python3.7/site-packages/yahoo_fin/stock_info.py in get_data(ticker, start_date, end_date, index_as_date, interval)
#      93
#      94     # get the date info
# ---> 95     temp_time = data["chart"]["result"][0]["timestamp"]
#      96
#      97
#
# KeyError: 'timestamp'

# %%
# portafolio en el que se invierte
tickers=["ESGV","ETHO","VT","XLK","VTI","IVV","QQQ","SMH","ARKW","ARKK","ESGU"]

dataframes=[]
for i in tickers:
       
    # Generamos el diccionario pada cada ticker
    string="{i}=ticker('{i}')".format(i=i)
    exec(string)
    
    string2="df_{i}={i}.getWeeks(12)".format(i=i)
    exec(string2)
    
    string3="df_{i}['ticker']='{i}'".format(i=i)
    exec(string3)
    
    string4="dataframes.append(df_{i})".format(i=i)
    exec(string4)
# Out:
# Creating ticker ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-b77f47ec7f93> in <module>
#      10
#      11     string2="df_{i}={i}.getWeeks(12)".format(i=i)
# ---> 12     exec(string2)
#      13
#      14     string3="df_{i}['ticker']='{i}'".format(i=i)
#
# <string> in <module>
#
# ~/Develop/tieup/tieup/codes/prod/model.py in getWeeks(self, i)
#     131         data = data.rename(columns={'index':'date'})
#     132
# --> 133         data_day = get_data(self.name , start_date = self.today)
#     134
#     135         date = dt.datetime.strptime(self.today, "%m/%d/%Y")
#
# ~/miniconda3/lib/python3.7/site-packages/yahoo_fin/stock_info.py in get_data(ticker, start_date, end_date, index_as_date, interval)
#      87
#      88     # add in adjclose
# ---> 89     frame["adjclose"] = data["chart"]["result"][0]["indicators"]["adjclose"][0]["adjclose"]
#      90
#      91     # get the date info
#
# KeyError: 'adjclose'

# %%
# Concatenamos todos los dataframes en solo uno
day_display=reduce(lambda x, y: pd.concat([x, y]), dataframes)
day_display

# %%
print("Getting results...")

# agregamos una columna de ponderacion de cada instrumento
day_display["pond"]=day_display["ticker"].apply(lambda x: ponderacion.get(x))

# Extraemos los montos que no tuvieron pnderacion
not_considered_per=1-sum(ponderacion.values())

# Guardamos lo que no se invirtio.. no se considera en la estimacion
rest=initial_amount*not_considered_per
invested=initial_amount-rest

# Agregamos columnas de cantidad inicial invertida y no invertida independiente del fondo
day_display["initial_invested_usd"]=initial_amount
day_display["real_invested"]=invested
day_display["not_invested"]=rest

print("Saving...")

save_gsheets(1,day_display)

print("Process completed")

# %%
day_display
# Out:
#          date       open       high        low      close   adjclose  volume  \
# 0  2020-05-20  53.459999  53.730000  53.340000  53.580002  53.386395  123000
# 1  2020-05-21  53.689999  53.689999  53.000000  53.230000  53.037659  211400
# 2  2020-05-22  53.080002  53.419998  52.990002  53.410000  53.217007   82200
# 3  2020-05-26  54.700001  54.790001  53.930000  53.950001  53.755058  150800
# 4  2020-05-27  54.630001  54.750000  53.410000  54.750000  54.552166  421400
# ..        ...        ...        ...        ...        ...        ...     ...
# 55 2020-08-07  75.589996  75.976997  75.379997  75.949997  75.949997  416500
# 56 2020-08-10  76.110001  76.144997  75.500000  76.050003  76.050003  373200
# 57 2020-08-11  76.339996  76.518997  75.289001  75.400002  75.400002  346300
# 58 2020-08-12  76.099998  76.760002  76.099998  76.559998  76.559998  332700
# 59 2020-08-12  76.099998  76.760002  76.099998  76.559998  76.559998  332716
#
#    ticker    pond  initial_invested_usd  real_invested  not_invested
# 0    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 1    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 2    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 3    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 4    ESGV  0.0412           6433.516045    6290.048637    143.467408
# ..    ...     ...                   ...            ...           ...
# 55   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 56   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 57   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 58   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 59   ESGU  0.0479           6433.516045    6290.048637    143.467408
#
# [660 rows x 12 columns]

# %%
day_display["acum"]=(day_display["real_invested"]*day_display["pond"])

# %%
day_display
# Out:
#          date       open       high        low      close   adjclose  volume  \
# 0  2020-05-20  53.459999  53.730000  53.340000  53.580002  53.386395  123000
# 1  2020-05-21  53.689999  53.689999  53.000000  53.230000  53.037659  211400
# 2  2020-05-22  53.080002  53.419998  52.990002  53.410000  53.217007   82200
# 3  2020-05-26  54.700001  54.790001  53.930000  53.950001  53.755058  150800
# 4  2020-05-27  54.630001  54.750000  53.410000  54.750000  54.552166  421400
# ..        ...        ...        ...        ...        ...        ...     ...
# 55 2020-08-07  75.589996  75.976997  75.379997  75.949997  75.949997  416500
# 56 2020-08-10  76.110001  76.144997  75.500000  76.050003  76.050003  373200
# 57 2020-08-11  76.339996  76.518997  75.289001  75.400002  75.400002  346300
# 58 2020-08-12  76.099998  76.760002  76.099998  76.559998  76.559998  332700
# 59 2020-08-12  76.099998  76.760002  76.099998  76.559998  76.559998  332716
#
#    ticker    pond  initial_invested_usd  real_invested  not_invested  \
# 0    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 1    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 2    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 3    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 4    ESGV  0.0412           6433.516045    6290.048637    143.467408
# ..    ...     ...                   ...            ...           ...
# 55   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 56   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 57   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 58   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 59   ESGU  0.0479           6433.516045    6290.048637    143.467408
#
#           acum
# 0   259.150004
# 1   259.150004
# 2   259.150004
# 3   259.150004
# 4   259.150004
# ..         ...
# 55  301.293330
# 56  301.293330
# 57  301.293330
# 58  301.293330
# 59  301.293330
#
# [660 rows x 13 columns]

# %%
day_display["change"]=((day_display["close"]/day_display["open"])-1)*100

# %%
day_display["inst"]=(1+day_display["change"])*
# Out:
#          date       open       high        low      close   adjclose  volume  \
# 0  2020-05-20  53.459999  53.730000  53.340000  53.580002  53.386395  123000
# 1  2020-05-21  53.689999  53.689999  53.000000  53.230000  53.037659  211400
# 2  2020-05-22  53.080002  53.419998  52.990002  53.410000  53.217007   82200
# 3  2020-05-26  54.700001  54.790001  53.930000  53.950001  53.755058  150800
# 4  2020-05-27  54.630001  54.750000  53.410000  54.750000  54.552166  421400
# ..        ...        ...        ...        ...        ...        ...     ...
# 55 2020-08-07  75.589996  75.976997  75.379997  75.949997  75.949997  416500
# 56 2020-08-10  76.110001  76.144997  75.500000  76.050003  76.050003  373200
# 57 2020-08-11  76.339996  76.518997  75.289001  75.400002  75.400002  346300
# 58 2020-08-12  76.099998  76.760002  76.099998  76.559998  76.559998  332700
# 59 2020-08-12  76.099998  76.760002  76.099998  76.559998  76.559998  332716
#
#    ticker    pond  initial_invested_usd  real_invested  not_invested  \
# 0    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 1    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 2    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 3    ESGV  0.0412           6433.516045    6290.048637    143.467408
# 4    ESGV  0.0412           6433.516045    6290.048637    143.467408
# ..    ...     ...                   ...            ...           ...
# 55   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 56   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 57   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 58   ESGU  0.0479           6433.516045    6290.048637    143.467408
# 59   ESGU  0.0479           6433.516045    6290.048637    143.467408
#
#           acum    profit    change
# 0   259.150004  0.224472  0.224472
# 1   259.150004 -0.856769 -0.856769
# 2   259.150004  0.621699  0.621699
# 3   259.150004 -1.371115 -1.371115
# 4   259.150004  0.219658  0.219658
# ..         ...       ...       ...
# 55  301.293330  0.476254  0.476254
# 56  301.293330 -0.078830 -0.078830
# 57  301.293330 -1.231327 -1.231327
# 58  301.293330  0.604467  0.604467
# 59  301.293330  0.604467  0.604467
#
# [660 rows x 15 columns]

# %%
# Out:
# 0.9999999999999999
